# %% [markdown]
# ## Bayesian linear regression (known error precision)

# %% [markdown]
# ###### Assumptions: polynomial basis functions, scalar output, scalar input, error precision known
# ###### Author: Rimple Sandhu, Carleton University; Email: rimple_sandhu@outlook.com

# %%
#!/usr/bin/python
import numpy as np
import numpy.linalg as la
import scipy.stats as st
import matplotlib.pyplot as plt
import matplotlib as mpl
import os, math, sys

# %% [markdown]
# #### Model definition (basis functions)

# %%
RHOtrue = 500
N = 2 # number of basis
def basisFun(Xin,ith):
    if ith==0: return np.sin(10.0*Xin)
    elif ith==1: return -np.sin(0.65*Xin)

# %% [markdown]
# #### Known parameters

# %%
m0 = np.ones(N)*0 # prior mean
RHO = RHOtrue # initial error precision
#pl.rcParams.update({'font.size':14})

# %%
Niter = 50
i1 = 0
i2 = 1
Pi1 = np.linspace(-4,10,Niter)
Pi2 = np.linspace(-4,10,Niter)
Pmsh = np.zeros((N*N,2))
P1,P2 = np.meshgrid(Pi1,Pi2)
alpha = [1e-02]*N # Starting hyper-parameter value 
#print(P1[0,:],P2[0,:])
#print(P1[:,0],P2[:,0])

# %% [markdown]
# #### Generate design matrix

# %%
Yobs = np.loadtxt('Ydata.dat') 
Xobs = np.loadtxt('Xdata.dat')
M = len(Yobs)
Phi = np.zeros((M,N))
for i in range(0,M):
    for j in range(0,N):
        Phi[i,j] = basisFun(Xobs[i],j)

# %% [markdown]
# #### Bayesian linear regression update

# %%
logEvid = np.zeros((Niter,Niter))
gof = np.zeros((Niter,Niter))
for i in range(0,Niter):
    for j in range(Niter):
        #alpha[2] = 1e+02
        alpha[i1] = np.power(10.0,P1[i,j])
        alpha[i2] = np.power(10.0,P2[i,j])
        GAMinv = np.identity(M)*RHO
        P0inv = np.diag(alpha)
        P0 = la.inv(P0inv)
        PMLEinv = np.matmul(np.matmul(np.transpose(Phi),GAMinv),Phi)
        Wmle = np.matmul(np.matmul(np.matmul(la.inv(PMLEinv),np.transpose(Phi)),GAMinv),Yobs)
        Pinv = P0inv + PMLEinv
        P = la.inv(Pinv) 
        m = np.matmul(P,np.matmul(P0inv,m0) + np.matmul(PMLEinv,Wmle))
        B = np.matmul(Phi,np.matmul(P0,np.transpose(Phi))) + la.inv(GAMinv)
        logEvid[i,j] = np.log(st.multivariate_normal.pdf(Yobs,np.matmul(Phi,m0),B))
        gof[i,j] = st.multivariate_normal.pdf(Yobs,np.matmul(Phi,m),np.identity(M)/RHOtrue)
        u1,s1,v1 = la.svd(PMLEinv)
        u2,s2,v2 = la.svd(Pinv)
        resNormMLE = la.norm(Yobs-np.matmul(Phi,Wmle))
        resNormMAP = la.norm(Yobs-np.matmul(Phi,m))
# Out:
# /home/rimple/Softwares/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: RuntimeWarning: divide by zero encountered in log

# %%
fig=plt.figure(3,figsize=(15,4))
#plt.pcolor(P1,P2,reshape(Yord,(N,N)),cmap='RdBu',vmin=0.28,vmax=0.38)
plt.subplot(1, 3, 1)
plt.pcolor(P1,P2,np.exp(logEvid),cmap='PuBu_r')
plt.colorbar()
plt.grid('on',linestyle='--')
plt.xlabel('alpha'+str(i1))
plt.ylabel('alpha'+str(i2))
plt.title('Evidence')
plt.savefig('alphavsLogevidjoint.jpg',bbox_inches='tight')


plt.subplot(1,3,2)
#plt.pcolor(P1,P2,reshape(Yord,(N,N)),cmap='RdBu',vmin=0.28,vmax=0.38)
plt.pcolor(P1,P2,-logEvid+gof,cmap='PuBu_r')
plt.colorbar()
plt.grid('on',linestyle='--')
plt.xlabel('alpha'+str(i1))
plt.ylabel('alpha'+str(i2))
plt.title('Complexity')
plt.savefig('alphavsLogevidjoint.jpg',bbox_inches='tight')
