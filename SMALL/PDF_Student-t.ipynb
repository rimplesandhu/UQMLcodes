# %% [markdown]
# ### Description: Student-t vs Gaussian

# %% [markdown]
# ###### Author: Rimple Sandhu, Carleton University; Email: rimple_sandhu@outlook.com

# %%
#!/usr/bin/python
from numpy import *
from scipy.stats import *
import matplotlib.pyplot as plt
import os
import math
import sys

# %%
df = 30000 # degree of freedom
mu = 4.0 # location parameter (mean of corrsponding gaussian)
sigma = 8.0 # scale parameter (standard deviation of corresponding gaussian)

# %%
Xgrid = linspace(mu-6*sigma,mu+6*sigma,100)
Xtdist = t(df,mu,sigma)
Xgdist = norm(mu,sigma)
print('Gaussian:  ',*Xgdist.stats(moments='mv'))
print('Student-t: ',*Xtdist.stats(moments='mv'))
print('K-L distance: ',entropy(Xtdist.pdf(Xgrid),Xgdist.pdf(Xgrid)))
# Out:
# Gaussian:   4.0 64.0
# Student-t:  4.0 64.00426695113008
# K-L distance:  1.9445036630626005e-09

# %%
fig = plt.figure(1)
plt.plot(Xgrid,Xtdist.pdf(Xgrid),'b-',label='Student-t')
plt.plot(Xgrid,Xgdist.pdf(Xgrid),'r-',label='Normal')
plt.grid(True)
plt.ylabel('pdf')
plt.xlabel('X')
plt.legend(loc='best', numpoints = 1)
#plt.savefig('PDF_X.pdf',bbox_inches='tight')

# %%
t.pdf(5,1000,5,2)
# Out:
# 0.19942127865685347
